# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(2)
# Out:
#      property_type                                            society  \
# 821          house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2834         house                                        independent
#
#          sector  price  price_per_sqft     area                  areaWithType  \
# 821   sector 26   31.5         35000.0   9000.0  Plot area 1000(836.13 sq.m.)
# 2834  sector 43   27.5         24366.0  11286.0  Plot area 1254(1048.5 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 821         7         9      3+       3.0  North-East  Moderately Old
# 2834        6         7      3+       3.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 821                   NaN         1000.0          NaN           1
# 2834                  NaN         1254.0          NaN           1
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well
df.shape
# Out:
# (3677, 23)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                    17
# price_per_sqft           17
# area                     17
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 19
# facing                 1045
# agePossession             0
# super_built_up_area    1802
# built_up_area          1987
# carpet_area            1805
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# dtype: int64

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 386          house            cloudnine cottages  sohna road road   5.50
# 671          house            emaar mgf marbella        sector 66  18.00
# 1200         house                   independent        sector 26  14.75
# 1261         house                   independent        sector 25  16.00
# 1349          flat                unitech vistas        sector 70   9.00
# 1425         house  project housing board colony        sector 31   8.00
# 1640         house        emaar the palm springs        sector 54  14.00
# 1839         house                unitech escape        sector 50  10.80
# 2211         house                   independent        sector 26  26.00
# 2290         house                  malibu towne        sector 47   8.50
# 2488         house                dlf city plots        sector 26  26.00
# 3046         house        emaar the palm springs        sector 54  24.00
# ...

# %%
df = df[(df['price_per_sqft'].isna()) | (df['price_per_sqft'] <= 50000)]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 1638          flat  signature global solera 2  sector 107   0.51
# 1648          flat          hcbs sports ville  sohna road   0.35
# 2111          flat      signature the roselia   sector 95   0.45
# 2651          flat            ramsons kshitij   sector 95   0.31
# 3021         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 1638             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 1648             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 2111             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 2651             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3021           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1638        2         2       1       3.0       North    New Property
# ...

# %%
df = df[(df['area'].isna()) | (df['area'] <= 100000)]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471
# Out:
#      property_type                    society           sector  price  \
# 818          house                independent        sector 26  18.40
# 48           house  ganpati heights apartment        sector 13   1.25
# 1123          flat                 rof ananda        sector 95   0.38
# 1796          flat                 rof ananda        sector 95   0.38
# 300          house      dlf city plot phase 4        sector 28  13.00
# 2             flat              pyramid elite        sector 86   0.46
# 2356          flat                 rof ananda        sector 95   0.33
# 115           flat      signature the serenas       sohna road   0.28
# 2666         house                independent        sector 25   7.30
# 3649          flat            ramsons kshitij        sector 95   0.24
# 2503          flat                 rof ananda        sector 95   0.21
# 1358         house                independent        sector 57   6.25
# ...

# %%
rows_to_drop = [818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471]

# Filter only those indexes which are < len(df)
valid_rows = [i for i in rows_to_drop if i < len(df)]

df.drop(df.index[valid_rows], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 818          house                independent        sector 26  18.40
# 48           house  ganpati heights apartment        sector 13   1.25
# 1123          flat                 rof ananda        sector 95   0.38
# 1796          flat                 rof ananda        sector 95   0.38
# 300          house      dlf city plot phase 4        sector 28  13.00
# 2356          flat                 rof ananda        sector 95   0.33
# 115           flat      signature the serenas       sohna road   0.28
# 2666         house                independent        sector 25   7.30
# 3649          flat            ramsons kshitij        sector 95   0.24
# 2503          flat                 rof ananda        sector 95   0.21
# 1358         house                independent        sector 57   6.25
# 3195         house                independent        sector 43   5.50
# ...

# %%
df.loc[48,'area'] = 115*9
df.loc[300,'area'] = 7250
df.loc[2666,'area'] = 5800
df.loc[1358,'area'] = 2660
df.loc[3195,'area'] = 2850
df.loc[2131,'area'] = 1812
df.loc[3088,'area'] = 2160
df.loc[3444,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      2064.620149
# std       2917.399478
# min        145.000000
# 25%       1261.000000
# 50%       1750.000000
# 75%       2340.000000
# max      98978.000000
# Name: area, dtype: float64

# %%
df.shape
# Out:
# (3649, 23)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                    17
# price_per_sqft           17
# area                     17
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 19
# facing                 1036
# agePossession             0
# super_built_up_area    1778
# built_up_area          1978
# carpet_area            1789
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# dtype: int64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3650.000000
# mean        3.345205
# std         1.849581
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 3618         house                  independent   sector 54   5.00
# 2611         house                  independent   sector 43   4.50
# 78           house                  independent  sector 17a   3.87
# 1493         house                  independent  sector 17a   3.93
# 1381         house                private house   sector 55   7.05
# 19           house                  independent   sector 54   5.50
# 372          house                  independent   sector 11   4.50
# 2039         house                  independent   sector 43  13.50
# 2096         house       luxury dlf city floors   sector 26  20.00
# 3038         house                  independent   sector 28    NaN
# 2137         house                  independent   sector 40  12.00
# 874          house               dlf city plots   sector 26  20.00
# 3698         house                  independent   sector 55   9.19
# ...

# %%
df = df[(df['bedRoom'].isna())|(df['bedRoom'] <= 10)]

# %%
df.shape
# Out:
# (3603, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3603.000000
# mean        3.210103
# std         1.400003
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %%
df['super_built_up_area'].describe()
# Out:
# count     1872.000000
# mean      1925.646127
# std        764.385034
# min         89.000000
# 25%       1479.750000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\3946634618.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3267         house  adani brahma samsara  sector 60  18.02         28200.0
# 2771         house           independent  sector 39   7.00         10000.0
# 2816         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 3267  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 2771  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 2816  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3267        12      3+       3.0  North-East  Relatively New
# 2771        11      3+       4.0  South-East  Relatively New
# 2816        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7585.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9022.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.shape
# Out:
# (3603, 23)

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\939662859.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1872.000000
# mean      1925.646127
# std        764.385034
# min         89.000000
# 25%       1479.750000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1323          flat  bestech park view grand spa    sector 81    4.7
# 3265          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1323          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3265          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1323        4         4      3+      19.0       North  Relatively New
# 3265        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1323               6926.0            NaN          NaN           0
# 3265              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %%
df = df[(df['super_built_up_area'].isna()) | (df['super_built_up_area'] <= 6000)]

# %%
df.shape
# Out:
# (3601, 23)

# %% [markdown]
# ### built up area

# %%
df=df[(df['built_up_area'].isna()) | (df['built_up_area']<=13000)]

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %%
df.shape
# Out:
# (3601, 23)

# %% [markdown]
# ### carpet area

# %%
df=df[(df['carpet_area'].isna())| (df['carpet_area']<=13000)]

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 818          house     independent  sector 26   18.4          1859.0  98978.0
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 818   Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6         8
# 2342                 Carpet area: 11000 (1021.93 sq.m.)        4         4
#
#      balcony  floorNum facing   agePossession  super_built_up_area  \
# 818       3+       4.0  South  Relatively New                  NaN
# 2342       3      13.0  North  Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 818             NaN      11000.0           0             1           1
# 2342            NaN      11000.0           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# ...

# %%
df.loc[2131,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 818          house     independent  sector 26   18.4          1859.0  98978.0
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 818   Plot area 502(419.74 sq.m.)Carpet area: 11000 ...      6.0       8.0
# 2342                 Carpet area: 11000 (1021.93 sq.m.)      4.0       4.0
#
#      balcony  floorNum facing   agePossession  super_built_up_area  \
# 818       3+       4.0  South  Relatively New                  NaN
# 2342       3      13.0  North  Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 818             NaN      11000.0         0.0           1.0         1.0
# 2342            NaN      11000.0         0.0           1.0         0.0
#
#       pooja room  others  furnishing_type  luxury_score
# ...

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7585.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9022.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3595, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7586.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8597.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9023.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 711          house                   independent   sector 26   20.0
# 901          house                   independent   sector 28   12.0
# 1090         house                   independent  sector 105    9.9
# 1509         house                   independent   sector 55    5.0
# 1526         house                dlf city plots   sector 26   19.0
# 2040         house                   independent   sector 43    9.5
# 2130         house                   independent   sector 26   19.0
# 3054         house  sushant lok 1 builder floors   sector 43   13.0
# 3108         house                   independent   sector 25   13.0
#
#       price_per_sqft    area  \
# 711          44444.0  4500.0
# 901          42194.0  2844.0
# 1090         49500.0  2000.0
# 1509         44444.0  1125.0
# 1526         42054.0  4518.0
# 2040         42222.0  2250.0
# 2130         42222.0  4500.0
# 3054         48148.0  2700.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(250.5)

# %%
df.shape
# Out:
# (3595, 23)

# %%
df[(df['area']/df['bedRoom'])<120]
# Out:
#      property_type                          society  \
# 37           house                      independent
# 48           house        ganpati heights apartment
# 229          house                        rk excelo
# 247          house                      independent
# 751          house                      independent
# 852          house                      independent
# 1224         house                      independent
# 1429         house                    sector 38 rwa
# 1562         house                      independent
# 1580         house                      independent
# 1696         house                         ss omnia
# 1737         house            rajendra park gurgaon
# 1773         house                    rattan garden
# 1953         house                   not applicable
# 1997         house                        jacobpura
# 2047         house                            ansal
# 2173         house             housing board colony
# ...

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2.0     47
# 3.0     33
# 5.0     28
# 6.0     17
# 4.0     17
# 9.0     15
# 8.0     12
# 10.0     8
# 7.0      8
# Name: count, dtype: int64

# %%
outliers_df=df[(df['area_room_ratio']<250)&(df['bedRoom']>3)]

# %%
outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\Yashasvi Pundir\AppData\Local\Temp\ipykernel_39140\3359844150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom']=round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250)&(df['bedRoom']<4)]
# Out:
#      property_type                     society      sector  price  \
# 97            flat              pivotal devaan   sector 84   0.34
# 128           flat    breez global heights 88a  sector 88a   0.50
# 198           flat  central park flower valley   sector 33   1.40
# 209           flat       pyramid urban homes 2   sector 86   0.42
# 211           flat             ramsons kshitij   sector 95   0.40
# ...            ...                         ...         ...    ...
# 3558          flat     signature global solera  sector 107   0.51
# 3579         house        shri shyam residency  sector 104   0.62
# 3590          flat     signature global solera  sector 107   0.30
# 3624         house                 independent    sector 4   0.67
# 3751         house                 independent   sector 21   0.45
#
#       price_per_sqft   area  \
# 97            7039.0  483.0
# 128           8375.0  597.0
# 198          21538.0  650.0
# 209           8485.0  495.0
# ...

# %%
df[(df['area_room_ratio']<250)&(df['bedRoom']>4)].shape
# Out:
# (15, 24)

# %%
df.shape
# Out:
# (3595, 24)

# %%
df=df[~((df['area_room_ratio']<250)&(df['bedRoom']>4))]

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df.shape
# Out:
# (3580, 24)

# %%
 df.head(10)
# Out:
#    property_type                      society       sector  price  \
# 0           flat      signature global park 4    sector 36   0.82
# 1           flat             smart world gems    sector 89   0.95
# 3           flat       breez global hill view   sohna road   0.32
# 4           flat  bestech park view sanskruti    sector 92   1.60
# 5           flat               suncity avenue   sector 102   0.48
# 6           flat               paras quartier  gwal pahari   7.50
# 7           flat       experion the heartsong   sector 108   2.00
# 8           flat      adani m2k oyster grande   sector 102   1.90
# 9          house                  independent   sector 105   1.20
# 10         house             dlf city phase 1    sector 26   4.50
#
#     price_per_sqft    area                                       areaWithType  \
# 0           7586.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1           8597.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# ...

# %%
df.isnull().sum()
# Out:
# property_type             1
# society                   2
# sector                    1
# price                    16
# price_per_sqft           16
# area                     16
# areaWithType              1
# bedRoom                   1
# bathroom                  1
# balcony                   1
# floorNum                 18
# facing                 1023
# agePossession             1
# super_built_up_area    1710
# built_up_area          1965
# carpet_area            1737
# study room                1
# servant room              1
# store room                1
# pooja room                1
# others                    1
# furnishing_type           1
# luxury_score              1
# area_room_ratio          16
# dtype: int64

# %%
df.to_csv('gurgaon_properties_outlier_treated.csv',index=False)
